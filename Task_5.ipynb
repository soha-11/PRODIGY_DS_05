# %%
# Task-5
# Analyze traffic accident data to identify patterns related to road conditions, weather, and
# time of day. Visualize accident hotspots and contributing factors.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/accident data.csv')
df.head()
# Out:
#            Index Accident_Severity Accident Date   Latitude  \
# 0  200701BS64157           Serious    05-06-2019  51.506187
# 1  200701BS65737           Serious    02-07-2019  51.495029
# 2  200701BS66127           Serious    26-08-2019  51.517715
# 3  200701BS66128           Serious    16-08-2019  51.495478
# 4  200701BS66837            Slight    03-09-2019  51.488576
#
#               Light_Conditions           District Area  Longitude  \
# 0        Darkness - lights lit  Kensington and Chelsea  -0.209082
# 1                     Daylight  Kensington and Chelsea  -0.173647
# 2  Darkness - lighting unknown  Kensington and Chelsea  -0.210215
# 3                     Daylight  Kensington and Chelsea  -0.202731
# 4        Darkness - lights lit  Kensington and Chelsea  -0.192487
#
#    Number_of_Casualties  Number_of_Vehicles Road_Surface_Conditions  \
# 0                   1.0                 2.0                     Dry
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269818 entries, 0 to 269817
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    269818 non-null  object
#  1   Accident_Severity        269818 non-null  object
#  2   Accident Date            269818 non-null  object
#  3   Latitude                 269801 non-null  float64
#  4   Light_Conditions         269818 non-null  object
#  5   District Area            269818 non-null  object
#  6   Longitude                269800 non-null  float64
#  7   Number_of_Casualties     269817 non-null  float64
#  8   Number_of_Vehicles       269817 non-null  float64
#  9   Road_Surface_Conditions  269465 non-null  object
#  10  Road_Type                267514 non-null  object
#  11  Urban_or_Rural_Area      269806 non-null  object
#  12  Weather_Conditions       263771 non-null  object
# ...

# %%
df.columns = df.columns.str.replace(' ', '_').str.replace('.', '').str.strip()
sns.set(style='whitegrid')

# %%
#Distribution of accident severity
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Accident_Severity', palette='viridis')
plt.title('Distribution of Accident Severity')
plt.xlabel('Accident Severity')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-12-a32b31ffbd07>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Accident_Severity', palette='viridis')

# %%
#Distribution of accidents by Light Conditions
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Light_Conditions', palette='viridis')
plt.title('Distribution of Accidents by Light Conditions')
plt.xlabel('Light Conditions')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-13-9a8c13dd0cf3>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Light_Conditions', palette='viridis')

# %%
# Distribution of accidents by Road Surface Conditions
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Road_Surface_Conditions', palette='viridis')
plt.title('Distribution of Accidents by Road Surface Conditions')
plt.xlabel('Road Surface Conditions')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-15-9fab4e1459c9>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Road_Surface_Conditions', palette='viridis')

# %%
# Distribution of accidents by weather conditions
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Weather_Conditions', palette='viridis')
plt.title('Distribution of Accidents by Weather Conditions')
plt.xlabel('Weather Conditions')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-16-6ed8629463d9>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Weather_Conditions', palette='viridis')

# %%
#Accident hotspots using a scatter plot of latitude and longitude
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Longitude', y='Latitude', hue='Accident_Severity', palette='viridis', alpha=0.7)
plt.title('Accident Hotspots by Severity')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
#Number of accidents by month
df['Accident Date'] = pd.to_datetime(df['Accident Date'], dayfirst=True, errors='coerce')
df['Month'] = df['Accident Date'].dt.month
plt.figure(figsize=(12, 6))
sns.countplot(x='Month', data=df, hue='Accident_Severity', palette='viridis')
plt.title('Accidents by Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.legend(title='Accident Severity')
plt.show()
